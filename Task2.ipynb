# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya-kandagaddala-2006/IIITH-Task/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ STEP 1: Install Required Libraries
# !pip install ultralytics yt-dlp opencv-python-headless

# ✅ STEP 2: Download a YouTube Video
video_url = "https://youtube.com/shorts/1BL8crVd0sA?si=qMpDcKQCLb6Nu7bB"
# !yt-dlp -f best -o input_video.mp4 "{video_url}"
# !ffmpeg -i input_video.mp4 -vf fps=1 frames/frame_%04d.jpg



# ✅ STEP 3: Extract Frames from the Video
import os
os.makedirs("frames", exist_ok=True)

# Extract 1 frame per second
# !ffmpeg -i input_video.mp4 -vf fps=1 frames/frame_%04d.jpg

# ✅ STEP 4: Zip the Frames Folder for Manual Annotation
# !zip -r frames.zip frames
print("✅ Download `frames.zip`, annotate the images (LabelImg or Roboflow), and re-upload the annotated dataset (YOLO format).")

# -------- WAIT FOR MANUAL ANNOTATION -------- #
# ⬇️ After you annotate the images (manually), upload your YOLO-formatted dataset below ⬇️
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 116.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 835.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
files.download('frames.zip')

# %%
# Create folder for frames
# !mkdir frames

# Extract 1 frame per second
# !ffmpeg -i "https://www.youtube.com/shorts/1BL8crVd0sA?feature=share"4 -vf fps=1 frames/frame_%04d.jpg
# Out:
# mkdir: cannot create directory ‘frames’: File exists
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !pip install yt-dlp
# !apt install ffmpeg -y
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import yt_dlp

url = "https://www.youtube.com/shorts/1BL8crVd0sA"

ydl_opts = {
    'outtmpl': 'video.mp4',  # Save as video.mp4
    'format': 'best[ext=mp4]'
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/1BL8crVd0sA
# [youtube] 1BL8crVd0sA: Downloading webpage
# [youtube] 1BL8crVd0sA: Downloading tv client config
# [youtube] 1BL8crVd0sA: Downloading tv player API JSON
# [youtube] 1BL8crVd0sA: Downloading ios player API JSON
# [youtube] 1BL8crVd0sA: Downloading m3u8 information
# [info] 1BL8crVd0sA: Downloading 1 format(s): 18
# [download] Destination: video.mp4
# [download] 100% of    1.74MiB in 00:00:00 at 2.71MiB/s

# %%
# !mkdir frames
# !ffmpeg -i video.mp4 -vf fps=1 frames/frame_%04d.jpg
# Out:
# mkdir: cannot create directory ‘frames’: File exists
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
