# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya-kandagaddala-2006/IIITH-Task/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Uninstall conflicting NumPy versions
# !pip uninstall numpy -y

# Install stable NumPy and YOLOv8
# !pip install numpy==1.23.5 ultralytics matplotlib seaborn
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 75.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
print("NumPy version:", np.__version__)

from ultralytics import YOLO
print("YOLOv8 installed successfully!")
# Out:
# NumPy version: 1.23.5
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 installed successfully!

# %%
# Train YOLOv8n for 15 epochs
# !yolo train data=african-wildlife.yaml model=yolov8n.pt epochs=15 imgsz=640
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !yolo train data=african-wildlife.yaml model=yolov8n.pt epochs=15
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !pip uninstall ultralytics -y  # Remove any broken installations
# !pip install ultralytics  # Reinstall the latest version
# Out:
# WARNING: Skipping ultralytics as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo train data=african-wildlife.yaml model=yolov8n.pt epochs=15
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 128MB/s]
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, display
import os

# Path to the training results folder
results_dir = '/content/runs/detect/train'

# List all image files in the results folder
result_images = [f for f in os.listdir(results_dir) if f.endswith('.png')]

# Display each image
for img_name in result_images:
    img_path = os.path.join(results_dir, img_name)
    print(f"Showing {img_name}:")
    display(Image(filename=img_path, width=600))
# Out:
# Showing F1_curve.png:
# Showing P_curve.png:
# Showing R_curve.png:
# Showing confusion_matrix_normalized.png:
# Showing results.png:
# Showing confusion_matrix.png:
# Showing PR_curve.png:

# %%
display(Image(filename='/content/runs/detect/train/confusion_matrix.png', width=800))

# %%
display(Image(filename='/content/runs/detect/train/results.png', width=800))

# %%
display(Image(filename='/content/runs/detect/train/val_batch0_pred.jpg', width=800))

# %%
from google.colab import files

# Zip the results folder
# !zip -r /content/results.zip /content/runs/detect/train

# Download
files.download('/content/results.zip')
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 39%)
#   adding: content/runs/detect/train/labels.jpg (deflated 24%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 9%)
#   adding: content/runs/detect/train/train_batch332.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train/P_curve.png (deflated 10%)
# ...
